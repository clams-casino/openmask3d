# %%
import os

import pickle

import numpy as np
import torch

import open3d as o3d

import matplotlib.pyplot as plt
import matplotlib.cm as cm
cmap = cm.get_cmap('jet')

from tqdm.notebook import tqdm
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
PREPROCESSED_3D_DIR = "/home/rsl_admin/openscene/openscene/data/matterport_3d/test"
INSTANCE_MASKS_FEATS_DIR = "/home/rsl_admin/openmask3d/cluster_output/test"


OUTPUT_DIR = "/home/rsl_admin/openmask3d/labeled_instance_outputs"

# %%
split = os.path.basename(PREPROCESSED_3D_DIR)

print(f"split: {split}")
# Out:
# split: test

# %% [markdown]
# ##
# First check that every 3D region has fused features for that region, pack this data for use later

# %%
from collections import namedtuple

# %%
RegionDataPaths = namedtuple("RegionDataPaths", ["data_3d_path", "masks_path", "mask_feats_path"])

# %%
import re

# %%
data_paths = []

for fname in os.listdir(PREPROCESSED_3D_DIR):
    region_name = fname.split('.')[0]
    
    masks_fname = f"{region_name}_masks.pt"
    
    
    masks_path = os.path.join(
        INSTANCE_MASKS_FEATS_DIR, 
        region_name, 
        f"{region_name}_masks.pt"
    )
    if not os.path.isfile(masks_path):
        print(f"no mask file at {masks_path}, skipping")
        continue
    
    
    
    
    mask_feats_path = os.path.join(
        INSTANCE_MASKS_FEATS_DIR, 
        region_name, 
        f"{region_name}_openmask3d_features.npy"
    )
    if not os.path.isfile(mask_feats_path):
        print(f"no mask features file at {mask_feats_path}, skipping")
        continue
    
              
    data_paths.append(
        RegionDataPaths(
            data_3d_path=os.path.join(PREPROCESSED_3D_DIR, fname),
            masks_path=masks_path,
            mask_feats_path=mask_feats_path,
        )
    )

# %%
for dp in data_paths:
    print(dp.data_3d_path)
    print(dp.masks_path)
    print(dp.mask_feats_path)
    print()
# Out:
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region23.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region23/yqstnuAEVhm_region23_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region23/yqstnuAEVhm_region23_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region13.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region13/q9vSo1VnCiC_region13_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region13/q9vSo1VnCiC_region13_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region27.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region27/wc2JMjhGNzB_region27_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region27/wc2JMjhGNzB_region27_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region0/5ZKStnWn8Zo_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region0/5ZKStnWn8Zo_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region20.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region20/jtcxE69GiFV_region20_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region20/jtcxE69GiFV_region20_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region5/YVUC4YcDtcY_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region5/YVUC4YcDtcY_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region30.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region30/fzynW3qQPVF_region30_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region30/fzynW3qQPVF_region30_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region18/fzynW3qQPVF_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region18/fzynW3qQPVF_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region7/UwV83HsGsw3_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region7/UwV83HsGsw3_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region13.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region13/jtcxE69GiFV_region13_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region13/jtcxE69GiFV_region13_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region24/UwV83HsGsw3_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region24/UwV83HsGsw3_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region4/Vt2qJdWjCF2_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region4/Vt2qJdWjCF2_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region9/jtcxE69GiFV_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region9/jtcxE69GiFV_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/gxdoqLR6rwA_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region2/gxdoqLR6rwA_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region2/gxdoqLR6rwA_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region0/rqfALeAoiTq_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region0/rqfALeAoiTq_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region16/ARNzJeq3xxb_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region16/ARNzJeq3xxb_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region19.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region19/WYY7iVyf5p8_region19_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region19/WYY7iVyf5p8_region19_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/gYvKGZ5eRqb_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/gYvKGZ5eRqb_region0/gYvKGZ5eRqb_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/gYvKGZ5eRqb_region0/gYvKGZ5eRqb_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region25.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region25/jtcxE69GiFV_region25_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region25/jtcxE69GiFV_region25_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region21/yqstnuAEVhm_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region21/yqstnuAEVhm_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region2/WYY7iVyf5p8_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region2/WYY7iVyf5p8_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region10.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region10/WYY7iVyf5p8_region10_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region10/WYY7iVyf5p8_region10_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/RPmz2sHmrrY_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region7/RPmz2sHmrrY_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region7/RPmz2sHmrrY_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region9/rqfALeAoiTq_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region9/rqfALeAoiTq_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region11/Vt2qJdWjCF2_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region11/Vt2qJdWjCF2_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region30.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region30/pa4otMbVnkk_region30_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region30/pa4otMbVnkk_region30_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region18/UwV83HsGsw3_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region18/UwV83HsGsw3_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region2/jtcxE69GiFV_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region2/jtcxE69GiFV_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region22.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region22/pa4otMbVnkk_region22_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region22/pa4otMbVnkk_region22_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region16/wc2JMjhGNzB_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region16/wc2JMjhGNzB_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region21/pa4otMbVnkk_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region21/pa4otMbVnkk_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region12/5ZKStnWn8Zo_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region12/5ZKStnWn8Zo_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region10.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region10/fzynW3qQPVF_region10_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region10/fzynW3qQPVF_region10_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region21/WYY7iVyf5p8_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region21/WYY7iVyf5p8_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region32.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region32/wc2JMjhGNzB_region32_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region32/wc2JMjhGNzB_region32_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region35.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region35/jtcxE69GiFV_region35_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region35/jtcxE69GiFV_region35_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region8/YFuZgdQ5vWj_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region8/YFuZgdQ5vWj_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region15/jtcxE69GiFV_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region15/jtcxE69GiFV_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region5/UwV83HsGsw3_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region5/UwV83HsGsw3_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region24/WYY7iVyf5p8_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region24/WYY7iVyf5p8_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region19.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region19/YFuZgdQ5vWj_region19_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region19/YFuZgdQ5vWj_region19_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region18/Vt2qJdWjCF2_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region18/Vt2qJdWjCF2_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region3/5ZKStnWn8Zo_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region3/5ZKStnWn8Zo_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region8/ARNzJeq3xxb_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region8/ARNzJeq3xxb_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region14/Vt2qJdWjCF2_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region14/Vt2qJdWjCF2_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region20.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region20/UwV83HsGsw3_region20_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region20/UwV83HsGsw3_region20_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region20.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region20/fzynW3qQPVF_region20_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region20/fzynW3qQPVF_region20_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region31.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region31/wc2JMjhGNzB_region31_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region31/wc2JMjhGNzB_region31_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region21/5ZKStnWn8Zo_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region21/5ZKStnWn8Zo_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region0/YVUC4YcDtcY_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region0/YVUC4YcDtcY_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region28.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region28/yqstnuAEVhm_region28_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region28/yqstnuAEVhm_region28_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region15/Vt2qJdWjCF2_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region15/Vt2qJdWjCF2_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region4/ARNzJeq3xxb_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region4/ARNzJeq3xxb_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region11/YFuZgdQ5vWj_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region11/YFuZgdQ5vWj_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region1/UwV83HsGsw3_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region1/UwV83HsGsw3_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region10.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region10/jtcxE69GiFV_region10_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region10/jtcxE69GiFV_region10_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region20.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region20/wc2JMjhGNzB_region20_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region20/wc2JMjhGNzB_region20_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region16/Vt2qJdWjCF2_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region16/Vt2qJdWjCF2_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region21/UwV83HsGsw3_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region21/UwV83HsGsw3_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region13.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region13/yqstnuAEVhm_region13_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region13/yqstnuAEVhm_region13_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/RPmz2sHmrrY_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region0/RPmz2sHmrrY_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region0/RPmz2sHmrrY_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region16/jtcxE69GiFV_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region16/jtcxE69GiFV_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region36.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region36/jtcxE69GiFV_region36_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region36/jtcxE69GiFV_region36_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/RPmz2sHmrrY_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region5/RPmz2sHmrrY_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region5/RPmz2sHmrrY_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region29.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region29/pa4otMbVnkk_region29_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region29/pa4otMbVnkk_region29_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region15/fzynW3qQPVF_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region15/fzynW3qQPVF_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region14/pa4otMbVnkk_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region14/pa4otMbVnkk_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region7/5ZKStnWn8Zo_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region7/5ZKStnWn8Zo_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region1/rqfALeAoiTq_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region1/rqfALeAoiTq_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region12/ARNzJeq3xxb_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region12/ARNzJeq3xxb_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region11/q9vSo1VnCiC_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region11/q9vSo1VnCiC_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region7/YVUC4YcDtcY_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region7/YVUC4YcDtcY_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region3/fzynW3qQPVF_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region3/fzynW3qQPVF_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region29.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region29/UwV83HsGsw3_region29_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region29/UwV83HsGsw3_region29_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region4/rqfALeAoiTq_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region4/rqfALeAoiTq_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region41.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region41/wc2JMjhGNzB_region41_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region41/wc2JMjhGNzB_region41_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region28.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region28/fzynW3qQPVF_region28_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region28/fzynW3qQPVF_region28_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region17/jtcxE69GiFV_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region17/jtcxE69GiFV_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region1/ARNzJeq3xxb_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region1/ARNzJeq3xxb_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region5/YFuZgdQ5vWj_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region5/YFuZgdQ5vWj_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region11/rqfALeAoiTq_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region11/rqfALeAoiTq_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region11/jtcxE69GiFV_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region11/jtcxE69GiFV_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region16/yqstnuAEVhm_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region16/yqstnuAEVhm_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region5/Vt2qJdWjCF2_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region5/Vt2qJdWjCF2_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region17/ARNzJeq3xxb_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region17/ARNzJeq3xxb_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region26.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region26/jtcxE69GiFV_region26_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region26/jtcxE69GiFV_region26_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region15/YFuZgdQ5vWj_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region15/YFuZgdQ5vWj_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region31.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region31/jtcxE69GiFV_region31_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region31/jtcxE69GiFV_region31_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region15/WYY7iVyf5p8_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region15/WYY7iVyf5p8_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region7/YFuZgdQ5vWj_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region7/YFuZgdQ5vWj_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region0/q9vSo1VnCiC_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region0/q9vSo1VnCiC_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/2t7WUuJeko7_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region5/2t7WUuJeko7_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region5/2t7WUuJeko7_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region17/q9vSo1VnCiC_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region17/q9vSo1VnCiC_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region1/jtcxE69GiFV_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region1/jtcxE69GiFV_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region6/jtcxE69GiFV_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region6/jtcxE69GiFV_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region24/wc2JMjhGNzB_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region24/wc2JMjhGNzB_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region5/WYY7iVyf5p8_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region5/WYY7iVyf5p8_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/2t7WUuJeko7_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region4/2t7WUuJeko7_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region4/2t7WUuJeko7_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region1/5ZKStnWn8Zo_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region1/5ZKStnWn8Zo_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region3/Vt2qJdWjCF2_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region3/Vt2qJdWjCF2_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region10.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region10/yqstnuAEVhm_region10_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region10/yqstnuAEVhm_region10_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region14/WYY7iVyf5p8_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region14/WYY7iVyf5p8_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region26.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region26/yqstnuAEVhm_region26_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region26/yqstnuAEVhm_region26_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region13.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region13/pa4otMbVnkk_region13_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region13/pa4otMbVnkk_region13_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region35.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region35/wc2JMjhGNzB_region35_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region35/wc2JMjhGNzB_region35_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region17/yqstnuAEVhm_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region17/yqstnuAEVhm_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region18/jtcxE69GiFV_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region18/jtcxE69GiFV_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region17/YFuZgdQ5vWj_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region17/YFuZgdQ5vWj_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region10.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region10/ARNzJeq3xxb_region10_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region10/ARNzJeq3xxb_region10_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region1/fzynW3qQPVF_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region1/fzynW3qQPVF_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region0/Vt2qJdWjCF2_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region0/Vt2qJdWjCF2_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region25.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region25/5ZKStnWn8Zo_region25_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region25/5ZKStnWn8Zo_region25_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region22.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region22/5ZKStnWn8Zo_region22_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region22/5ZKStnWn8Zo_region22_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region24/jtcxE69GiFV_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region24/jtcxE69GiFV_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region6/q9vSo1VnCiC_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region6/q9vSo1VnCiC_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region34.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region34/pa4otMbVnkk_region34_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region34/pa4otMbVnkk_region34_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region11/pa4otMbVnkk_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region11/pa4otMbVnkk_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region17/UwV83HsGsw3_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region17/UwV83HsGsw3_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region23.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region23/WYY7iVyf5p8_region23_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region23/WYY7iVyf5p8_region23_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region26.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region26/UwV83HsGsw3_region26_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region26/UwV83HsGsw3_region26_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region9/Vt2qJdWjCF2_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region9/Vt2qJdWjCF2_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region33.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region33/pa4otMbVnkk_region33_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region33/pa4otMbVnkk_region33_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region24/yqstnuAEVhm_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region24/yqstnuAEVhm_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region6/5ZKStnWn8Zo_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region6/5ZKStnWn8Zo_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region25.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region25/wc2JMjhGNzB_region25_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region25/wc2JMjhGNzB_region25_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region24.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region24/Vt2qJdWjCF2_region24_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region24/Vt2qJdWjCF2_region24_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region6/UwV83HsGsw3_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region6/UwV83HsGsw3_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region2/q9vSo1VnCiC_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region2/q9vSo1VnCiC_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/Vt2qJdWjCF2_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region1/Vt2qJdWjCF2_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/Vt2qJdWjCF2_region1/Vt2qJdWjCF2_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region8/UwV83HsGsw3_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region8/UwV83HsGsw3_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region8/yqstnuAEVhm_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region8/yqstnuAEVhm_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region16/fzynW3qQPVF_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region16/fzynW3qQPVF_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region17/rqfALeAoiTq_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region17/rqfALeAoiTq_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region29.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region29/fzynW3qQPVF_region29_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region29/fzynW3qQPVF_region29_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region23.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region23/jtcxE69GiFV_region23_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region23/jtcxE69GiFV_region23_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region21/YFuZgdQ5vWj_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region21/YFuZgdQ5vWj_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region32.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region32/pa4otMbVnkk_region32_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region32/pa4otMbVnkk_region32_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region30.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region30/jtcxE69GiFV_region30_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region30/jtcxE69GiFV_region30_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/gxdoqLR6rwA_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region3/gxdoqLR6rwA_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region3/gxdoqLR6rwA_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region14/ARNzJeq3xxb_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region14/ARNzJeq3xxb_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/2t7WUuJeko7_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region3/2t7WUuJeko7_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/2t7WUuJeko7_region3/2t7WUuJeko7_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/RPmz2sHmrrY_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region2/RPmz2sHmrrY_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region2/RPmz2sHmrrY_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region11/5ZKStnWn8Zo_region11_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region11/5ZKStnWn8Zo_region11_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region14/UwV83HsGsw3_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region14/UwV83HsGsw3_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region18/q9vSo1VnCiC_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region18/q9vSo1VnCiC_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region14/wc2JMjhGNzB_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region14/wc2JMjhGNzB_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region1/wc2JMjhGNzB_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region1/wc2JMjhGNzB_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region3/wc2JMjhGNzB_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region3/wc2JMjhGNzB_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region26.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region26/5ZKStnWn8Zo_region26_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region26/5ZKStnWn8Zo_region26_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region4/UwV83HsGsw3_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region4/UwV83HsGsw3_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region21.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region21/rqfALeAoiTq_region21_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region21/rqfALeAoiTq_region21_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region4/q9vSo1VnCiC_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region4/q9vSo1VnCiC_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region7.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region7/jtcxE69GiFV_region7_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region7/jtcxE69GiFV_region7_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region26.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region26/pa4otMbVnkk_region26_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region26/pa4otMbVnkk_region26_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region4/yqstnuAEVhm_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region4/yqstnuAEVhm_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region8/rqfALeAoiTq_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region8/rqfALeAoiTq_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region27.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region27/yqstnuAEVhm_region27_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region27/yqstnuAEVhm_region27_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region27.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region27/pa4otMbVnkk_region27_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region27/pa4otMbVnkk_region27_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/gxdoqLR6rwA_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region0/gxdoqLR6rwA_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/gxdoqLR6rwA_region0/gxdoqLR6rwA_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region8/5ZKStnWn8Zo_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region8/5ZKStnWn8Zo_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region33.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region33/wc2JMjhGNzB_region33_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region33/wc2JMjhGNzB_region33_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region1/WYY7iVyf5p8_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region1/WYY7iVyf5p8_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region11.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region11/ARNzJeq3xxb_region11_masks.pt
# ...
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region6/wc2JMjhGNzB_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region6/wc2JMjhGNzB_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region12/UwV83HsGsw3_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region12/UwV83HsGsw3_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region20.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region20/rqfALeAoiTq_region20_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region20/rqfALeAoiTq_region20_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region12/pa4otMbVnkk_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region12/pa4otMbVnkk_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region15.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region15/UwV83HsGsw3_region15_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region15/UwV83HsGsw3_region15_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region16/WYY7iVyf5p8_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region16/WYY7iVyf5p8_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region4/jtcxE69GiFV_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region4/jtcxE69GiFV_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region8/q9vSo1VnCiC_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region8/q9vSo1VnCiC_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region9/wc2JMjhGNzB_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region9/wc2JMjhGNzB_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region12/YFuZgdQ5vWj_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region12/YFuZgdQ5vWj_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region17/wc2JMjhGNzB_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region17/wc2JMjhGNzB_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region8.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region8/YVUC4YcDtcY_region8_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region8/YVUC4YcDtcY_region8_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region17/fzynW3qQPVF_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region17/fzynW3qQPVF_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region9/q9vSo1VnCiC_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region9/q9vSo1VnCiC_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region0/YFuZgdQ5vWj_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region0/YFuZgdQ5vWj_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region22.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region22/jtcxE69GiFV_region22_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region22/jtcxE69GiFV_region22_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region6/WYY7iVyf5p8_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region6/WYY7iVyf5p8_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region30.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region30/wc2JMjhGNzB_region30_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region30/wc2JMjhGNzB_region30_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region1/pa4otMbVnkk_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region1/pa4otMbVnkk_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region9/yqstnuAEVhm_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region9/yqstnuAEVhm_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region4/YFuZgdQ5vWj_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region4/YFuZgdQ5vWj_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region6.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region6/pa4otMbVnkk_region6_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region6/pa4otMbVnkk_region6_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region0/ARNzJeq3xxb_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region0/ARNzJeq3xxb_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/pa4otMbVnkk_region31.pth
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region31/pa4otMbVnkk_region31_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/pa4otMbVnkk_region31/pa4otMbVnkk_region31_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region17.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region17/5ZKStnWn8Zo_region17_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region17/5ZKStnWn8Zo_region17_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region19.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region19/jtcxE69GiFV_region19_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region19/jtcxE69GiFV_region19_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/RPmz2sHmrrY_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region4/RPmz2sHmrrY_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/RPmz2sHmrrY_region4/RPmz2sHmrrY_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region22.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region22/WYY7iVyf5p8_region22_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region22/WYY7iVyf5p8_region22_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region3.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region3/q9vSo1VnCiC_region3_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region3/q9vSo1VnCiC_region3_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region16/YFuZgdQ5vWj_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region16/YFuZgdQ5vWj_region16_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region9/ARNzJeq3xxb_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region9/ARNzJeq3xxb_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/WYY7iVyf5p8_region0.pth
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region0/WYY7iVyf5p8_region0_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/WYY7iVyf5p8_region0/WYY7iVyf5p8_region0_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region1/q9vSo1VnCiC_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region1/q9vSo1VnCiC_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region4/5ZKStnWn8Zo_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region4/5ZKStnWn8Zo_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/ARNzJeq3xxb_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region5/ARNzJeq3xxb_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/ARNzJeq3xxb_region5/ARNzJeq3xxb_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region9/YVUC4YcDtcY_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region9/YVUC4YcDtcY_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/fzynW3qQPVF_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region14/fzynW3qQPVF_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/fzynW3qQPVF_region14/fzynW3qQPVF_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region4.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region4/YVUC4YcDtcY_region4_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region4/YVUC4YcDtcY_region4_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/jtcxE69GiFV_region5.pth
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region5/jtcxE69GiFV_region5_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/jtcxE69GiFV_region5/jtcxE69GiFV_region5_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region18.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region18/5ZKStnWn8Zo_region18_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region18/5ZKStnWn8Zo_region18_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region14/yqstnuAEVhm_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region14/yqstnuAEVhm_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YFuZgdQ5vWj_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region14/YFuZgdQ5vWj_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YFuZgdQ5vWj_region14/YFuZgdQ5vWj_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region2/YVUC4YcDtcY_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region2/YVUC4YcDtcY_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region9.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region9/UwV83HsGsw3_region9_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region9/UwV83HsGsw3_region9_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/YVUC4YcDtcY_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region1/YVUC4YcDtcY_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/YVUC4YcDtcY_region1/YVUC4YcDtcY_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region13.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region13/wc2JMjhGNzB_region13_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region13/wc2JMjhGNzB_region13_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/5ZKStnWn8Zo_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region2/5ZKStnWn8Zo_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/5ZKStnWn8Zo_region2/5ZKStnWn8Zo_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/wc2JMjhGNzB_region40.pth
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region40/wc2JMjhGNzB_region40_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/wc2JMjhGNzB_region40/wc2JMjhGNzB_region40_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region12.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region12/rqfALeAoiTq_region12_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region12/rqfALeAoiTq_region12_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region2.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region2/UwV83HsGsw3_region2_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region2/UwV83HsGsw3_region2_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/yqstnuAEVhm_region1.pth
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region1/yqstnuAEVhm_region1_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/yqstnuAEVhm_region1/yqstnuAEVhm_region1_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/rqfALeAoiTq_region22.pth
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region22/rqfALeAoiTq_region22_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/rqfALeAoiTq_region22/rqfALeAoiTq_region22_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/q9vSo1VnCiC_region14.pth
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region14/q9vSo1VnCiC_region14_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/q9vSo1VnCiC_region14/q9vSo1VnCiC_region14_openmask3d_features.npy
#
# /home/rsl_admin/openscene/openscene/data/matterport_3d/test/UwV83HsGsw3_region16.pth
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region16/UwV83HsGsw3_region16_masks.pt
# /home/rsl_admin/openmask3d/cluster_output/test/UwV83HsGsw3_region16/UwV83HsGsw3_region16_openmask3d_features.npy

# %% [markdown]
# ### Set up class vocabulary
# This step requires the user to select a label set to query the segmentations on

# %%
labelset_selection_dropdown  = widgets.Dropdown(
    options=[
        "HABITAT_OGN_LABELS",
        "MATTERPORT_REGION_LABELS",
    ],
    disabled=False,
)

display(labelset_selection_dropdown)
# Out:
# Dropdown(options=('HABITAT_OGN_LABELS', 'MATTERPORT_REGION_LABELS'), value='HABITAT_OGN_LABELS')

# %%
if labelset_selection_dropdown.value == "HABITAT_OGN_LABELS":
    from comparison_label_mappings import HABITAT_OGN_LABELS, HABITAT_OGN_LABELS_TO_TEXT_PROMPTS
    
    labelset = list(HABITAT_OGN_LABELS)
    label_text_prompts = [
        HABITAT_OGN_LABELS_TO_TEXT_PROMPTS[label] for label in HABITAT_OGN_LABELS
    ]
    
    labelset_name = "object"
    
    
elif labelset_selection_dropdown.value == "MATTERPORT_REGION_LABELS":
    from comparison_label_mappings import MATTERPORT_REGION_LABELS, MATTERPORT_REGION_LABELS_TO_TEXT_PROMPTS
    
    labelset = list(MATTERPORT_REGION_LABELS)
    label_text_prompts = [
        MATTERPORT_REGION_LABELS_TO_TEXT_PROMPTS[label] for label in MATTERPORT_REGION_LABELS
    ]
    
    labelset_name = "region"
    
else: 
    raise Exception

# %%
label_to_ind = {label: i for i, label in enumerate(labelset)}

print(label_to_ind)
# Out:
# {'bathroom': 0, 'bedroom': 1, 'closet': 2, 'dining room': 3, 'garage': 4, 'hallway': 5, 'library': 6, 'laundryroom/mudroom': 7, 'kitchen': 8, 'living room': 9, 'meetingroom/conferenceroom': 10, 'office': 11, 'porch/terrace/deck/driveway': 12, 'rec/game': 13, 'stairs': 14, 'utilityroom/toolroom': 15, 'tv': 16, 'workout/gym/exercise': 17, 'balcony': 18, 'bar': 19, 'classroom': 20, 'spa/sauna': 21, 'entryway/foyer/lobby': 22, 'outdoor': 23, 'dining booth': 24, 'other room': 25}

# %%
import clip

# %%
def extract_text_feature(labelset, model_name="ViT-L/14@336px"):
    """
    Modified from Openscene
    """
    print("Loading CLIP {} model...".format(model_name))
    clip_pretrained, _ = clip.load(model_name, device='cuda', jit=False)
    clip_pretrained.eval()
    print("Finish loading")

    if isinstance(labelset, str):
        lines = labelset.split(',')
    elif isinstance(labelset, list):
        lines = labelset
    else:
        raise NotImplementedError
    
    labels = []
    for line in lines:
        label = line
        labels.append(label)
    text = clip.tokenize(labels)
    text = text.cuda()
    with torch.no_grad():
        text_features = clip_pretrained.encode_text(text)
    text_features = text_features / text_features.norm(dim=-1, keepdim=True)

    return text_features.cpu().numpy()

# %%
label_feats = extract_text_feature(
    label_text_prompts,
)

print(label_feats.shape)
# Out:
# Loading CLIP ViT-L/14@336px model...
# Finish loading
# (26, 768)

# %% [markdown]
# ## We may want to remove redundant/overlaping mask instances

# %%
REMOVE_REDUNDANT_INSTANCES = True

IOU_THRESHOLD = 0.6

# %%
def aabb_intersect(
    min_1, max_1, 
    min_2, max_2
):
    if np.any(max_1 < min_2) or np.any(max_2 < min_1):
        return False
    
    return True

# %%
def aabb_iou(    
    min_1, max_1, 
    min_2, max_2
):
    EPS = 1e-5  # could have zero volume (e.g. 2D) boxes
    
    intersect_min = np.maximum(min_1, min_2)
    intersect_max = np.minimum(max_1, max_2)
    
    intersect_lengths = np.maximum(0, intersect_max - intersect_min)
    
    intersect_volume = np.prod(intersect_lengths) + EPS
    
    volume_1 = np.prod(max_1 - min_1) + EPS
    volume_2 = np.prod(max_2 - min_2) + EPS
    
    return intersect_volume / (volume_1 + volume_2 - intersect_volume)

# %% [markdown]
# ## Generate and save the segmentations

# %%
save_dirname = f"{labelset_name}-{split}"

if REMOVE_REDUNDANT_INSTANCES:
    save_dirname = f"filt_iou_{IOU_THRESHOLD}/{save_dirname}"

os.makedirs(
    os.path.join(OUTPUT_DIR, save_dirname),
    exist_ok=True
)

print(f"saving to: {os.path.join(OUTPUT_DIR, save_dirname)}")
# Out:
# saving to: /home/rsl_admin/openmask3d/labeled_instance_outputs/filt_iou_0.6/region-test

# %%
for dp in tqdm(data_paths):
    
    data_3d = torch.load(dp.data_3d_path)
    points, colors, _ = data_3d
    
    masks = torch.load(dp.masks_path).astype(bool)
    
    mask_feats = np.load(dp.mask_feats_path)
    
#     print(type(points))
#     print(points.shape)
    
#     print(type(masks))
#     print(masks.shape)
    
#     print(type(mask_feats))
#     print(mask_feats.shape)
    
    assert points.shape[0] == masks.shape[0]
    assert masks.shape[1] == mask_feats.shape[0]
    

    instance_boxes = []
    for i in range(masks.shape[1]):
        instance_points = points[masks[:,i]].astype(np.float16)
        
        min_bound = np.min(instance_points, axis=0)
        max_bound = np.max(instance_points, axis=0)
        
        instance_boxes.append(
            (min_bound, max_bound)
        )
        

    if REMOVE_REDUNDANT_INSTANCES:

        nr_box_inds = []
        
        for box_1_ind, box_1 in enumerate(instance_boxes):
            redundant = False
            
            for box_2_ind in nr_box_inds:
                box_2 = instance_boxes[box_2_ind]
                             
                if not aabb_intersect(box_1[0], box_1[1], box_2[0], box_2[1]):
                    continue
                    
                iou = aabb_iou(box_1[0], box_1[1], box_2[0], box_2[1])
                if iou > IOU_THRESHOLD:
                    redundant = True
                    break
            
            if not redundant:
                nr_box_inds.append(box_1_ind)
        
        
#         print(len(instance_boxes))
#         print(len(nr_box_inds))
        
    
        masks = masks[:, nr_box_inds]
        mask_feats = mask_feats[nr_box_inds, :]
        
        instance_boxes = [
            box for i, box in enumerate(instance_boxes) if i in nr_box_inds
        ]
        
        
    instance_preds = np.argmax(mask_feats @ label_feats.T, axis=1).astype(int)

    
    out = {
        "points": points,
        "masks": masks,
        "instance_preds": instance_preds,
        "instance_min_max_bounds": tuple(instance_boxes),
        "label_to_ind": label_to_ind,
    }
    
    save_filename = os.path.basename(dp.data_3d_path).replace('.pth', '.pkl')
    save_path = os.path.join(
        os.path.join(OUTPUT_DIR, save_dirname, save_filename),
    )
    
    
    with open(save_path, 'wb') as f:
        pickle.dump(out, f)
# Out:
#   0%|          | 0/406 [00:00<?, ?it/s]

# %% [markdown]
# ## Visualize an output segmentation

# %%
MATTERPORT_DIR = "/media/rsl_admin/T7/matterport/data/v1/scans"

# %%
np.random.seed(0)

# %%
# output_fname = np.random.choice(
#     os.listdir(os.path.join(OUTPUT_DIR, save_dirname))
# )

output_fname = "2t7WUuJeko7_region1.pkl"

output_path = os.path.join(OUTPUT_DIR, save_dirname, output_fname)

with open(output_path, 'rb') as f:
    out = pickle.load(f)
    
print(f"loaded {output_fname}")
# Out:
# loaded 2t7WUuJeko7_region1.pkl

# %%
scan_name = output_fname.split('_')[0]

scan_mesh = o3d.io.read_triangle_mesh(
    os.path.join(MATTERPORT_DIR, f"{scan_name}/{scan_name}/house_segmentations/{scan_name}.ply")
)

# %%
label_to_ind = out["label_to_ind"]
labels = label_to_ind.keys()

# %%
print(labels)
# Out:
# dict_keys(['bathroom', 'bedroom', 'closet', 'dining room', 'garage', 'hallway', 'library', 'laundryroom/mudroom', 'kitchen', 'living room', 'meetingroom/conferenceroom', 'office', 'porch/terrace/deck/driveway', 'rec/game', 'stairs', 'utilityroom/toolroom', 'tv', 'workout/gym/exercise', 'balcony', 'bar', 'classroom', 'spa/sauna', 'entryway/foyer/lobby', 'outdoor', 'dining booth', 'other room'])

# %%
label_dropdown = widgets.Dropdown(
    options=['all'] + sorted(labels),
    disabled=False,
)

display(label_dropdown)
# Out:
# Dropdown(options=('all', 'balcony', 'bar', 'bathroom', 'bedroom', 'classroom', 'closet', 'dining booth', 'dini…

# %%
instance_inds = np.where(out["instance_preds"] == label_to_ind[label_dropdown.value])[0]

instance_pcds = []
instance_boxes = []
for ind in instance_inds:
    instance_color = np.random.uniform(size=3)
    
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(
        out["points"][out["masks"][:,ind]]
    )
    pcd.paint_uniform_color(instance_color)
    
    instance_pcds.append(pcd)
    
    box_bounds = out["instance_min_max_bounds"][ind]
    box = o3d.geometry.AxisAlignedBoundingBox(
        box_bounds[0], box_bounds[1]
    )
    box.color = instance_color
    
    instance_boxes.append(box)
    
    
    
#     o3d.visualization.draw_geometries(
#         [scan_mesh, pcd, box]
#     )

# %%
o3d.visualization.draw_geometries(
    [scan_mesh] + instance_pcds + instance_boxes
)
